# %%
import pandas as pd
from openai import OpenAI
import random
import os
import re

# %%
category = "mecaz"
idiom = "Üstüne almak"
model ="gpt-4-turbo"

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key="OpenAI Key",
)

# %%
if not os.path.exists('response_data.csv'):
    pd.DataFrame(columns=["raw_response","category", "idiom", "type"]).to_csv('response_data.csv', index=False)

# %%
df_structured = pd.DataFrame(columns=["submission", "category", "idiom", "type"])

# %% [markdown]
# **Zero-Shot**

# %%
class ChatSession:
    def __init__(self, category, model=model):
        self.model = model
        system_message = f"Türkçe, anadiliniz olduğundan, dilimizi zengin ve yaratıcı biçimlerde kullanmalısın. Lütfen cümlelerinizde benzer yapılar kullanmaktan kaçının ve deyimleri doğru ve {category} anlamıyla kullanarak cümleler oluşturun. İnsan isimlerini kullanarak cümle kurmamalısın !"
        print(system_message)
        self.messages = [
            {"role": "system", "content": system_message}
        ]

    def get_completion(self, user_prompt):
        # Add the new user message
        self.messages.append({"role": "user", "content": user_prompt})
        
        # Make the API call
        response = client.chat.completions.create(
            model=self.model,
            messages=self.messages,
        )

        # Retrieve the response and append to messages to maintain context
        ai_response = response.choices[0].message.content.strip()
        self.messages.append({"role": "assistant", "content": ai_response})
        response_df = pd.DataFrame(columns=["raw_response", "idiom","type","category"])
        new_entry = {
            "raw_response": ai_response,
            "idiom": idiom,
            "type": type,
            "category":category
        }
        response_df = response_df.append(new_entry, ignore_index=True)
        response_df.to_csv('response_data.csv', mode='a', header=False, index=False)
        return ai_response

# %%
chat_session = ChatSession(category=category)
# Out:
# Türkçe, anadiliniz olduğundan, dilimizi zengin ve yaratıcı biçimlerde kullanmalısın. Lütfen cümlelerinizde benzer yapılar kullanmaktan kaçının ve deyimleri doğru ve mecaz anlamıyla kullanarak cümleler oluşturun. İnsan isimlerini kullanarak cümle kurmamalısın !

# %%
type = "Zero-shot"
step = 8

# %%
prompt = f"""
"{idiom}", Türkçe bir deyimidir. Bu deyimi hem gerçek hem de mecaz anlamda kullanabiliriz. Lütfen bu deyimi {category} anlamda kullanarak örnek 5 tane cümle yaz. Yanıt olarak sadace cümleleri dön.
"""
print(prompt)
print("\n")
responses = []
for i in range(step):
    result = chat_session.get_completion(prompt)
    responses.append(result)
# Out:
# "Üstüne almak", Türkçe bir deyimidir. Bu deyimi hem gerçek hem de mecaz anlamda kullanabiliriz. Lütfen bu deyimi mecaz anlamda kullanarak örnek 5 tane cümle yaz. Yanıt olarak sadace cümleleri dön.

# %%
responses
# Out:
# ['1. Müdürün genel uyarısının ardından, hepsi kafalarını öne eğdi ama sadece biri sözleri üstüne alarak hemen aksiyona geçti.\n2. Projede yaşanan aksaklıkla ilgili kimse konuşmak istemezken, o, hataları üstüne alıp çözüm bulmaya çalıştı.\n3. Eleştiriler genellikle genel olarak söylenir ama bazen biri çıkar bu sözleri üstüne alır ve işleri rayına oturtur.\n4. Arkadaş gruplarında sıkça karşılaşılan sorunlarda, herkes sessiz kalabilir ama cesur yürekler bu sorunları üstüne alarak ortamı yumuşatır.\n5. Herkes projedeki başarısızlıkla ilgili endişeliyken, proje yöneticisi cesaretle tüm suçu üstüne alarak ekip üyelerini korudu.',
#  '1. Grup içinde yapılan uyarıları kimse ciddiye almazken, o, söylenenleri üstüne alarak hemen işe koyuldu.\n2. Toplantıda dile getirilen eksiklikler üzerine konuşulduğunda, o her zamanki gibi eleştiriyi üstüne alıp düzeltmek için adım attı.\n3. Kimse kabul etmek istemezken, sorunun farkında olan tek kişi olarak o, hatayı üstüne alarak özür diledi.\n4. Her ne kadar kimsenin hatası olarak görünmese de, o, olumsuz sonucu üstüne alarak herkesin rahatlamasını sağladı.\n5. Ekip üyeleri genellikle hataları kabul etmekten çekinirken, o, içtenlikle tüm eksiklikleri üstüne alarak iş birliğinin önemini gösterdi.',
#  '1. Toplantıda yapılan suçlamalar karşısında başka kimse sesini çıkarmazken, o lafı üstüne alarak özür diledi.\n2. Sert bir eleştiri alan takım, içlerindeki bir kişi gerekeni yaparak tüm sorumluluğu üstüne aldı.\n3. Bir hata olduğunda, derhal üstüne alınan kişi, sorunu çözmek için ilk adımı atan olur.\n4. Herkesin kaçındığı görevleri o üstüne alarak, takdir toplamayı başardı.\n5. Ders sırasında öğretmen kimsenin dikkatini çekemediğinde, bir öğrenci hatayı üstüne alarak dikkati üzerine çekti.',
#  '1. Eleştirileri duyunca, o doğrudan üstüne alınarak hemen düzeltmeler yapmaya başladı.\n2. Takımın başarısızlığı üzerine söylenenler karşısında, o üstüne alınarak sorumluluğu üstlendi.\n3. Mutfakta yaşanan karışıklıkla ilgili kimse konuşmayınca, o üstüne alınarak işleri yoluna koymaya karar verdi.\n4. Projede yapılan hataları, lider üstüne alınca ekip içerisinde rahatlama hissedildi.\n5. Süpervizörün genel uyarısını üstüne alınan çalışan, işlerini daha ciddiye almaya başladı.',
#  '1. Toplantıda dile getirilen eleştiriler karşısında kimse sesini çıkarmazken, o sözleri üstüne alıp hemen iyileştirme sürecine girişti.\n2. Proje yöneticisi, oluşan sorunlarla ilgili tüm sorumluluğu üstüne alarak ekibinin motivasyonunu korudu.\n3. Genel müdürenin yapıcı eleştirilerini üstüne alarak performansını artırmak için ekstra çaba gösterdi.\n4. Hatalar zinciri ortaya çıktığında, o şirketteki krizi yönetmek için tüm suçu üstüne alarak öne çıktı.\n5. Eleştiriler genellikle olumsuz bir hava yaratır, ancak onu üstüne alanlar bu durumu kişisel gelişimleri için bir fırsat olarak değerlendirir.',
#  '1. Kritik toplantı sonrası, eleştirilen noktaları üstüne alarak kendini geliştirmek için adımlar atmaya başladı.\n2. Şirketteki başarısızlıkla ilgili yapılan yorumlar karşısında, genel müdür olayı üstüne alıp tüm sorumluluğu üstlendi.\n3. Öğretmenin dikkat çektiği disiplin sorununu üstüne alarak, sınıfın daha düzenli olmasına katkı sağladı.\n4. Takımdaki kötü performansın ele alındığı toplantıda, antrenör başarısızlığı üstüne alarak, stratejileri gözden geçireceğini söyledi.\n5. Eleştirileri doğrudan üstüne alıp, profesyonel anlamda daha da ilerlemek için gerekenleri yapmaya başladı.',
#  '1. Ekipçe alınan eleştirileri üstüne alınca, herkesin üzerindeki yük biraz olsun hafifledi.\n2. Toplantıda dile getirilen sorunları üstüne alarak, derhal çözüm yolları aramaya koyuldu.\n3. Müdür, genel başarısızlık üzerine yapılan yorumları üstüne alıp, tüm sorumluluğu kabul etti.\n4. Tüm ekip sessiz kalırken, o söylenenleri üstüne alarak aksiyon planı hazırlamaya başladı.\n5. Projedeki gecikmeleri üstüne alarak, çalışma temposunu artırdı ve ekibi motive etti.',
#  '1. Toplantıda dile getirilen kusurlar karşısında, bütün ekip sus pus olurken, bir tek o sözleri üstüne alarak düzeltmeye başladı.\n2. Müdür genel eleştiriler yaptığında, kimse suçu kabul etmezken o eleştirileri üstüne alıp, gerekli değişiklikleri yapma sözü verdi.\n3. Ders sırasında yapılan uyarıları üstüne alınca, sınıfın en çalışkan öğrencisi olmak için çaba göstermeye başladı.\n4. Tüm sorumlulukları üstüne alınca, proje daha sistemli ve verimli bir şekilde ilerlemeye başladı.\n5. Şikayetler artınca, o dostane tavsiyeyi üstüne alarak kendini ve yaklaşımlarını gözden geçirmeye karar verdi.']

# %%
def parse_and_structure_data(raw_responses_list, idiom, category, response_type):
    # Initialize the list to store structured data
    structured_data = []
    # Iterate through each block of responses
    for block in raw_responses_list:
        # Split each block into individual sentences
        sentences = block.split('\n')
        # Remove the numbering from each sentence and strip leading/trailing whitespace
        clean_sentences = [sentence.split('. ', 1)[-1].strip() for sentence in sentences]
        # For each sentence, append a tuple with the structured data
        for sentence in clean_sentences:
            structured_data.append((sentence, category, idiom, response_type))
    return structured_data

# %%
structured_data = parse_and_structure_data(responses, idiom, category, type)

new_df= pd.DataFrame(structured_data, columns=["submission", "category", "idiom", "type"])
new_df
# Out:
#                                            submission category         idiom  \
# 0   Müdürün genel uyarısının ardından, hepsi kafal...    mecaz  Üstüne almak
# 1   Projede yaşanan aksaklıkla ilgili kimse konuşm...    mecaz  Üstüne almak
# 2   Eleştiriler genellikle genel olarak söylenir a...    mecaz  Üstüne almak
# 3   Arkadaş gruplarında sıkça karşılaşılan sorunla...    mecaz  Üstüne almak
# 4   Herkes projedeki başarısızlıkla ilgili endişel...    mecaz  Üstüne almak
# 5   Grup içinde yapılan uyarıları kimse ciddiye al...    mecaz  Üstüne almak
# 6   Toplantıda dile getirilen eksiklikler üzerine ...    mecaz  Üstüne almak
# 7   Kimse kabul etmek istemezken, sorunun farkında...    mecaz  Üstüne almak
# 8   Her ne kadar kimsenin hatası olarak görünmese ...    mecaz  Üstüne almak
# 9   Ekip üyeleri genellikle hataları kabul etmekte...    mecaz  Üstüne almak
# 10  Toplantıda yapılan suçlamalar karşısında başka...    mecaz  Üstüne almak
# 11  Sert bir eleştiri alan takım, içlerindeki bir ...    mecaz  Üstüne almak
# 12  Bir hata olduğunda, derhal üstüne alınan kişi,...    mecaz  Üstüne almak
# 13  Herkesin kaçındığı görevleri o üstüne alarak, ...    mecaz  Üstüne almak
# 14  Ders sırasında öğretmen kimsenin dikkatini çek...    mecaz  Üstüne almak
# 15  Eleştirileri duyunca, o doğrudan üstüne alınar...    mecaz  Üstüne almak
# 16  Takımın başarısızlığı üzerine söylenenler karş...    mecaz  Üstüne almak
# 17  Mutfakta yaşanan karışıklıkla ilgili kimse kon...    mecaz  Üstüne almak
# 18  Projede yapılan hataları, lider üstüne alınca ...    mecaz  Üstüne almak
# 19  Süpervizörün genel uyarısını üstüne alınan çal...    mecaz  Üstüne almak
# 20  Toplantıda dile getirilen eleştiriler karşısın...    mecaz  Üstüne almak
# 21  Proje yöneticisi, oluşan sorunlarla ilgili tüm...    mecaz  Üstüne almak
# 22  Genel müdürenin yapıcı eleştirilerini üstüne a...    mecaz  Üstüne almak
# 23  Hatalar zinciri ortaya çıktığında, o şirkettek...    mecaz  Üstüne almak
# 24  Eleştiriler genellikle olumsuz bir hava yaratı...    mecaz  Üstüne almak
# 25  Kritik toplantı sonrası, eleştirilen noktaları...    mecaz  Üstüne almak
# 26  Şirketteki başarısızlıkla ilgili yapılan yorum...    mecaz  Üstüne almak
# 27  Öğretmenin dikkat çektiği disiplin sorununu üs...    mecaz  Üstüne almak
# 28  Takımdaki kötü performansın ele alındığı topla...    mecaz  Üstüne almak
# 29  Eleştirileri doğrudan üstüne alıp, profesyonel...    mecaz  Üstüne almak
# 30  Ekipçe alınan eleştirileri üstüne alınca, herk...    mecaz  Üstüne almak
# 31  Toplantıda dile getirilen sorunları üstüne ala...    mecaz  Üstüne almak
# 32  Müdür, genel başarısızlık üzerine yapılan yoru...    mecaz  Üstüne almak
# 33  Tüm ekip sessiz kalırken, o söylenenleri üstün...    mecaz  Üstüne almak
# 34  Projedeki gecikmeleri üstüne alarak, çalışma t...    mecaz  Üstüne almak
# 35  Toplantıda dile getirilen kusurlar karşısında,...    mecaz  Üstüne almak
# 36  Müdür genel eleştiriler yaptığında, kimse suçu...    mecaz  Üstüne almak
# 37  Ders sırasında yapılan uyarıları üstüne alınca...    mecaz  Üstüne almak
# 38  Tüm sorumlulukları üstüne alınca, proje daha s...    mecaz  Üstüne almak
# 39  Şikayetler artınca, o dostane tavsiyeyi üstüne...    mecaz  Üstüne almak
#
#          type
# 0   Zero-shot
# 1   Zero-shot
# 2   Zero-shot
# 3   Zero-shot
# 4   Zero-shot
# 5   Zero-shot
# 6   Zero-shot
# 7   Zero-shot
# 8   Zero-shot
# 9   Zero-shot
# 10  Zero-shot
# 11  Zero-shot
# 12  Zero-shot
# 13  Zero-shot
# 14  Zero-shot
# 15  Zero-shot
# 16  Zero-shot
# 17  Zero-shot
# 18  Zero-shot
# 19  Zero-shot
# 20  Zero-shot
# 21  Zero-shot
# 22  Zero-shot
# 23  Zero-shot
# 24  Zero-shot
# 25  Zero-shot
# 26  Zero-shot
# 27  Zero-shot
# 28  Zero-shot
# 29  Zero-shot
# 30  Zero-shot
# 31  Zero-shot
# 32  Zero-shot
# 33  Zero-shot
# 34  Zero-shot
# 35  Zero-shot
# 36  Zero-shot
# 37  Zero-shot
# 38  Zero-shot
# 39  Zero-shot

# %%
new_df = new_df[new_df['submission']!=""]
new_df.reset_index(drop=True,inplace=True)
new_df
# Out:
#                                            submission category         idiom  \
# 0   Müdürün genel uyarısının ardından, hepsi kafal...    mecaz  Üstüne almak
# 1   Projede yaşanan aksaklıkla ilgili kimse konuşm...    mecaz  Üstüne almak
# 2   Eleştiriler genellikle genel olarak söylenir a...    mecaz  Üstüne almak
# 3   Arkadaş gruplarında sıkça karşılaşılan sorunla...    mecaz  Üstüne almak
# 4   Herkes projedeki başarısızlıkla ilgili endişel...    mecaz  Üstüne almak
# 5   Grup içinde yapılan uyarıları kimse ciddiye al...    mecaz  Üstüne almak
# 6   Toplantıda dile getirilen eksiklikler üzerine ...    mecaz  Üstüne almak
# 7   Kimse kabul etmek istemezken, sorunun farkında...    mecaz  Üstüne almak
# 8   Her ne kadar kimsenin hatası olarak görünmese ...    mecaz  Üstüne almak
# 9   Ekip üyeleri genellikle hataları kabul etmekte...    mecaz  Üstüne almak
# 10  Toplantıda yapılan suçlamalar karşısında başka...    mecaz  Üstüne almak
# 11  Sert bir eleştiri alan takım, içlerindeki bir ...    mecaz  Üstüne almak
# 12  Bir hata olduğunda, derhal üstüne alınan kişi,...    mecaz  Üstüne almak
# 13  Herkesin kaçındığı görevleri o üstüne alarak, ...    mecaz  Üstüne almak
# 14  Ders sırasında öğretmen kimsenin dikkatini çek...    mecaz  Üstüne almak
# 15  Eleştirileri duyunca, o doğrudan üstüne alınar...    mecaz  Üstüne almak
# 16  Takımın başarısızlığı üzerine söylenenler karş...    mecaz  Üstüne almak
# 17  Mutfakta yaşanan karışıklıkla ilgili kimse kon...    mecaz  Üstüne almak
# 18  Projede yapılan hataları, lider üstüne alınca ...    mecaz  Üstüne almak
# 19  Süpervizörün genel uyarısını üstüne alınan çal...    mecaz  Üstüne almak
# 20  Toplantıda dile getirilen eleştiriler karşısın...    mecaz  Üstüne almak
# 21  Proje yöneticisi, oluşan sorunlarla ilgili tüm...    mecaz  Üstüne almak
# 22  Genel müdürenin yapıcı eleştirilerini üstüne a...    mecaz  Üstüne almak
# 23  Hatalar zinciri ortaya çıktığında, o şirkettek...    mecaz  Üstüne almak
# 24  Eleştiriler genellikle olumsuz bir hava yaratı...    mecaz  Üstüne almak
# 25  Kritik toplantı sonrası, eleştirilen noktaları...    mecaz  Üstüne almak
# 26  Şirketteki başarısızlıkla ilgili yapılan yorum...    mecaz  Üstüne almak
# 27  Öğretmenin dikkat çektiği disiplin sorununu üs...    mecaz  Üstüne almak
# 28  Takımdaki kötü performansın ele alındığı topla...    mecaz  Üstüne almak
# 29  Eleştirileri doğrudan üstüne alıp, profesyonel...    mecaz  Üstüne almak
# 30  Ekipçe alınan eleştirileri üstüne alınca, herk...    mecaz  Üstüne almak
# 31  Toplantıda dile getirilen sorunları üstüne ala...    mecaz  Üstüne almak
# 32  Müdür, genel başarısızlık üzerine yapılan yoru...    mecaz  Üstüne almak
# 33  Tüm ekip sessiz kalırken, o söylenenleri üstün...    mecaz  Üstüne almak
# 34  Projedeki gecikmeleri üstüne alarak, çalışma t...    mecaz  Üstüne almak
# 35  Toplantıda dile getirilen kusurlar karşısında,...    mecaz  Üstüne almak
# 36  Müdür genel eleştiriler yaptığında, kimse suçu...    mecaz  Üstüne almak
# 37  Ders sırasında yapılan uyarıları üstüne alınca...    mecaz  Üstüne almak
# 38  Tüm sorumlulukları üstüne alınca, proje daha s...    mecaz  Üstüne almak
# 39  Şikayetler artınca, o dostane tavsiyeyi üstüne...    mecaz  Üstüne almak
#
#          type
# 0   Zero-shot
# 1   Zero-shot
# 2   Zero-shot
# 3   Zero-shot
# 4   Zero-shot
# 5   Zero-shot
# 6   Zero-shot
# 7   Zero-shot
# 8   Zero-shot
# 9   Zero-shot
# 10  Zero-shot
# 11  Zero-shot
# 12  Zero-shot
# 13  Zero-shot
# 14  Zero-shot
# 15  Zero-shot
# 16  Zero-shot
# 17  Zero-shot
# 18  Zero-shot
# 19  Zero-shot
# 20  Zero-shot
# 21  Zero-shot
# 22  Zero-shot
# 23  Zero-shot
# 24  Zero-shot
# 25  Zero-shot
# 26  Zero-shot
# 27  Zero-shot
# 28  Zero-shot
# 29  Zero-shot
# 30  Zero-shot
# 31  Zero-shot
# 32  Zero-shot
# 33  Zero-shot
# 34  Zero-shot
# 35  Zero-shot
# 36  Zero-shot
# 37  Zero-shot
# 38  Zero-shot
# 39  Zero-shot

# %%
df_structured = pd.concat([df_structured, new_df], ignore_index=True)
df_structured
# Out:
#                                            submission category         idiom  \
# 0   Toplantıdaki eleştirileri üstüne alındı ve hem...    mecaz  Üstüne almak
# 1   Hoca sınıfta genel bir uyarı yaptığında, herke...    mecaz  Üstüne almak
# 2   Projedeki aksaklıklar geçtiğimiz hafta ortaya ...    mecaz  Üstüne almak
# 3   Her ne kadar takım olarak kaybetmiş olsalar da...    mecaz  Üstüne almak
# 4   Öğretmen ders anlatırken yapılan hataları öğre...    mecaz  Üstüne almak
# 5   Öğretmen sınıfta disiplinsizlik üzerine konuşu...    mecaz  Üstüne almak
# 6   Yönetici eleştirileri üstüne alarak tüm soruml...    mecaz  Üstüne almak
# 7   Ahmet dedikoduları üstüne alındı ve huzursuz o...    mecaz  Üstüne almak
# 8   Müdür genel bir uyarı yaptığında, bütün ekip s...    mecaz  Üstüne almak
# 9   Sunum sırasında yapılan eleştirilere kimse tep...    mecaz  Üstüne almak
# 10  Toplantı sırasında yapılan eleştiriler genelde...    mecaz  Üstüne almak
# 11  Ekip liderimiz, projede yaşanan gecikmelerden ...    mecaz  Üstüne almak
# 12  Şef, mutfağın dağınıklığından bahsedince, yeni...    mecaz  Üstüne almak
# 13  Derse geç kalan öğrenciler arasında, sadece bi...    mecaz  Üstüne almak
# 14  Takım olarak kötü performans sergiledik ama ka...    mecaz  Üstüne almak
# 15  Toplantıda dile getirilen problemeler karşısın...    mecaz  Üstüne almak
# 16  Şirketin başarısızlıklarını ele alırken, yönet...    mecaz  Üstüne almak
# 17  Aile içindeki anlaşmazlık büyürken, anne tüm s...    mecaz  Üstüne almak
# 18  Değerlendirme toplantısında yapılan eleştirile...    mecaz  Üstüne almak
# 19  Koç, takımın kötü performansını üstüne alarak,...    mecaz  Üstüne almak
# 20  Müdürün genel uyarısının ardından, hepsi kafal...    mecaz  Üstüne almak
# 21  Projede yaşanan aksaklıkla ilgili kimse konuşm...    mecaz  Üstüne almak
# 22  Eleştiriler genellikle genel olarak söylenir a...    mecaz  Üstüne almak
# 23  Arkadaş gruplarında sıkça karşılaşılan sorunla...    mecaz  Üstüne almak
# 24  Herkes projedeki başarısızlıkla ilgili endişel...    mecaz  Üstüne almak
# 25  Grup içinde yapılan uyarıları kimse ciddiye al...    mecaz  Üstüne almak
# 26  Toplantıda dile getirilen eksiklikler üzerine ...    mecaz  Üstüne almak
# 27  Kimse kabul etmek istemezken, sorunun farkında...    mecaz  Üstüne almak
# 28  Her ne kadar kimsenin hatası olarak görünmese ...    mecaz  Üstüne almak
# 29  Ekip üyeleri genellikle hataları kabul etmekte...    mecaz  Üstüne almak
# 30  Toplantıda yapılan suçlamalar karşısında başka...    mecaz  Üstüne almak
# 31  Sert bir eleştiri alan takım, içlerindeki bir ...    mecaz  Üstüne almak
# 32  Bir hata olduğunda, derhal üstüne alınan kişi,...    mecaz  Üstüne almak
# 33  Herkesin kaçındığı görevleri o üstüne alarak, ...    mecaz  Üstüne almak
# 34  Ders sırasında öğretmen kimsenin dikkatini çek...    mecaz  Üstüne almak
# 35  Eleştirileri duyunca, o doğrudan üstüne alınar...    mecaz  Üstüne almak
# 36  Takımın başarısızlığı üzerine söylenenler karş...    mecaz  Üstüne almak
# 37  Mutfakta yaşanan karışıklıkla ilgili kimse kon...    mecaz  Üstüne almak
# 38  Projede yapılan hataları, lider üstüne alınca ...    mecaz  Üstüne almak
# 39  Süpervizörün genel uyarısını üstüne alınan çal...    mecaz  Üstüne almak
# 40  Toplantıda dile getirilen eleştiriler karşısın...    mecaz  Üstüne almak
# 41  Proje yöneticisi, oluşan sorunlarla ilgili tüm...    mecaz  Üstüne almak
# 42  Genel müdürenin yapıcı eleştirilerini üstüne a...    mecaz  Üstüne almak
# 43  Hatalar zinciri ortaya çıktığında, o şirkettek...    mecaz  Üstüne almak
# 44  Eleştiriler genellikle olumsuz bir hava yaratı...    mecaz  Üstüne almak
# 45  Kritik toplantı sonrası, eleştirilen noktaları...    mecaz  Üstüne almak
# 46  Şirketteki başarısızlıkla ilgili yapılan yorum...    mecaz  Üstüne almak
# 47  Öğretmenin dikkat çektiği disiplin sorununu üs...    mecaz  Üstüne almak
# 48  Takımdaki kötü performansın ele alındığı topla...    mecaz  Üstüne almak
# 49  Eleştirileri doğrudan üstüne alıp, profesyonel...    mecaz  Üstüne almak
# 50  Ekipçe alınan eleştirileri üstüne alınca, herk...    mecaz  Üstüne almak
# 51  Toplantıda dile getirilen sorunları üstüne ala...    mecaz  Üstüne almak
# 52  Müdür, genel başarısızlık üzerine yapılan yoru...    mecaz  Üstüne almak
# 53  Tüm ekip sessiz kalırken, o söylenenleri üstün...    mecaz  Üstüne almak
# 54  Projedeki gecikmeleri üstüne alarak, çalışma t...    mecaz  Üstüne almak
# 55  Toplantıda dile getirilen kusurlar karşısında,...    mecaz  Üstüne almak
# 56  Müdür genel eleştiriler yaptığında, kimse suçu...    mecaz  Üstüne almak
# 57  Ders sırasında yapılan uyarıları üstüne alınca...    mecaz  Üstüne almak
# 58  Tüm sorumlulukları üstüne alınca, proje daha s...    mecaz  Üstüne almak
# 59  Şikayetler artınca, o dostane tavsiyeyi üstüne...    mecaz  Üstüne almak
#
#          type
# 0   Zero-shot
# 1   Zero-shot
# 2   Zero-shot
# 3   Zero-shot
# 4   Zero-shot
# 5   Zero-shot
# 6   Zero-shot
# 7   Zero-shot
# 8   Zero-shot
# 9   Zero-shot
# 10  Zero-shot
# 11  Zero-shot
# 12  Zero-shot
# 13  Zero-shot
# 14  Zero-shot
# 15  Zero-shot
# 16  Zero-shot
# 17  Zero-shot
# 18  Zero-shot
# 19  Zero-shot
# 20  Zero-shot
# 21  Zero-shot
# 22  Zero-shot
# 23  Zero-shot
# 24  Zero-shot
# 25  Zero-shot
# 26  Zero-shot
# 27  Zero-shot
# 28  Zero-shot
# 29  Zero-shot
# 30  Zero-shot
# 31  Zero-shot
# 32  Zero-shot
# 33  Zero-shot
# 34  Zero-shot
# 35  Zero-shot
# 36  Zero-shot
# 37  Zero-shot
# 38  Zero-shot
# 39  Zero-shot
# 40  Zero-shot
# 41  Zero-shot
# 42  Zero-shot
# 43  Zero-shot
# 44  Zero-shot
# 45  Zero-shot
# 46  Zero-shot
# 47  Zero-shot
# 48  Zero-shot
# 49  Zero-shot
# 50  Zero-shot
# 51  Zero-shot
# 52  Zero-shot
# 53  Zero-shot
# 54  Zero-shot
# 55  Zero-shot
# 56  Zero-shot
# 57  Zero-shot
# 58  Zero-shot
# 59  Zero-shot

# %% [markdown]
# **Enhanced-prompting**

# %%
gerçek_örnekler=['"Ağzı yanmak" deyimi sıcak bir içecekten, sıcak bir yiyecekten, sıcak buhardan, sıcak yüzeylere dokunmaktan, acı bir yemekten ya da kimyasal maddelere maruz kalmaktan kaynaklanan durumlar için kullanılabilir.',
                 '"Burnunu sürtmek" deyimi sert bir zemine düşmekten, bir duvara ya da sert bir yüzeye çarpmaktan, sert bir zeminde yuvarlanmaktan, bir nesneye sürtünmekten ya da yere düşerken yüzüne darbe almaktan kaynaklanan durumlar için kullanılabilir.',
                 '"Ateşle oynamak" deyimi bir ateş kaynağına dokunmaktan, yanıcı maddelerle deney yapmaktan, açık alevlerle çalışmaktan, ateşle dolu bir alanda bulunmaktan ya da ateşle tehlikeli bir şekilde oynamaktan kaynaklanan durumlar için kullanılabilir.',
                 '"Kuyruğuna basmak" deyimi bir hayvanın kuyruğunun yanlışlıkla basılmasından, bir hayvanın kuyruğunu kapıya sıkıştırmaktan, bir hayvanın kuyruğunu bir nesneyle vurmak ya da üzerine düşmekten, ya da bir hayvanın kuyruğunu çekmekten kaynaklanan durumlar için kullanılabilir.',
                 '"Çamur atmak" deyimi bir kişinin fiziksel olarak çamur fırlatmasından, bir grup insan arasında çamur topları oynarken birbirlerine çamur atılmasından, bir çocuğun yağmurlu bir günde çamurlu bir alanda oynarken çamur sıçratmasından, bir inşaat alanında veya bir tarlada çalışırken çamurlu ellerle birbirine dokunmaktan ya da bir festival veya kutlamada çamur banyosu yaparken çamur atılmasından kaynaklanan durumlar için kullanılabilir.']

# %%
mecaz_örnekler = ['"Ağzı yanmak" deyimi birine güvenip aldatıldığında, ekonomik bir zarar yaşandığında, kişisel bir hüsranla karşılaşıldığında, yanıltıcı bir bilgiye dayanarak yanılgıya düştüğünde ya da beklenen bir sonucun tam tersiyle karşılaşıldığında kullanılabilir'
                  '"Ateşle oynamak" deyimi mecaz anlamda, tehlikeli bir kişiyle işbirliği yaparken, riskli bir finansal yatırım yaparken, yasal sınırları zorlayacak bir eyleme girişirken, toplumsal normlara karşı gelindiğinde ya da genel kabul görmeyen bir stratejiyi benimserken kullanılabilir.',
                  '"Kuyruğuna basmak" deyimi bir kişinin hassas bir konusuna dokunduğunda, başkasının gizli zayıflıklarını ortaya çıkardığında, birisinin özel alanına izinsiz girildiğinde, birinin geçmiş hatalarını gündeme getirdiğinde ya da bir kişinin gizli planlarını bozduğunda kullanılabilir.',
                  '"Çamur atmak" deyimi bir kişiye iftira atıldığında, bir rakibin itibarını zedelemek için yanlış bilgiler yayıldığında, bir kişi hakkında asılsız dedikodular çıkarıldığında, birisinin kamu önündeki imajına zarar vermek amacıyla negatif yorumlar yapıldığında ya da bir kişinin başarılarını gölgelemek için kasıtlı olarak kötüleyici söylemlerde bulunulduğunda kullanılabilir.',
                  '"Burnunu sürtmek" deyimi bir hata yaptıktan sonra alay konusu olduğunda, başarısız bir girişimden sonra eleştiri aldığında, bir konuda beklenmedik bir yenilgi yaşandığında, hatalı bir kararın sonuçlarına katlanıldığında ya da bir kişinin gururu kırıldığında kullanılabilir.']

# %%
type = "Enhanced-prompting"
step = 1

# %%
class ChatSession:
    def __init__(self, category, model=model):
        self.model = model
        system_message = f"Türkçe, anadiliniz olduğundan, dilimizi zengin ve yaratıcı biçimlerde kullanmalısın. İstenilen isteğe göre yanıt vermeye özen göster. Deyimin kelime köklerini değiştirmeyerek. İnsan isimlerini kullanarak cümle kurmamalısın !"
        print(system_message)
        self.messages = [
            {"role": "system", "content": system_message}
        ]

    def get_completion(self, user_prompt):
        # Add the new user message
        self.messages.append({"role": "user", "content": user_prompt})
        
        # Make the API call
        response = client.chat.completions.create(
            model=self.model,
            messages=self.messages,
        )

        # Retrieve the response and append to messages to maintain context
        ai_response = response.choices[0].message.content.strip()
        self.messages.append({"role": "assistant", "content": ai_response})
        response_df = pd.DataFrame(columns=["raw_response", "idiom","type","category"])
        new_entry = {
            "raw_response": ai_response,
            "idiom": idiom,
            "type": type,
            "category":category
        }
        response_df = response_df.append(new_entry, ignore_index=True)
        response_df.to_csv('response_data.csv', mode='a', header=False, index=False)
        return ai_response

if category == "gerçek":
    örnek = random.choice(gerçek_örnekler)
    prompt = f"""
    {örnek} Benzer bir şekilde, "{idiom}" deyiminin {category} anlamda kullanıldığı durumları listeler misin?
    """
else:
    örnek = random.choice(mecaz_örnekler)
    prompt = f"""
    {örnek} Benzer bir şekilde, "{idiom}" deyiminin {category} anlamda kullanıldığı durumları listeler misin?
    """

# %%
chat_session = ChatSession(category=category)
# Out:
# Türkçe, anadiliniz olduğundan, dilimizi zengin ve yaratıcı biçimlerde kullanmalısın. İstenilen isteğe göre yanıt vermeye özen göster. Deyimin kelime köklerini değiştirmeyerek. İnsan isimlerini kullanarak cümle kurmamalısın !

# %%
print(prompt)
print("\n")

for i in range(step):
    result = chat_session.get_completion(prompt)
    print(result)
# Out:
#     "Ağzı yanmak" deyimi birine güvenip aldatıldığında, ekonomik bir zarar yaşandığında, kişisel bir hüsranla karşılaşıldığında, yanıltıcı bir bilgiye dayanarak yanılgıya düştüğünde ya da beklenen bir sonucun tam tersiyle karşılaşıldığında kullanılabilir"Ateşle oynamak" deyimi mecaz anlamda, tehlikeli bir kişiyle işbirliği yaparken, riskli bir finansal yatırım yaparken, yasal sınırları zorlayacak bir eyleme girişirken, toplumsal normlara karşı gelindiğinde ya da genel kabul görmeyen bir stratejiyi benimserken kullanılabilir. Benzer bir şekilde, "Üstüne almak" deyiminin mecaz anlamda kullanıldığı durumları listeler misin?
# Elbette, "üstüne almak" deyimi genellikle bir sorumluluğu kabul etmek, suçlamayı veya eleştiriyi kabullenmek veya bir görevi üzerine almak anlamında kullanılır. Bu deyim, çeşitli bağlamlarda mecaz anlamda ifade edilebilir:
#
# 1. Bir projenin ya da işin sorumluluğunu üzerine almak: Bu durum, bir kişinin özellikle zor veya büyük bir işte liderlik etmeyi kabul etmesiyle ilgilidir.
# 2. Eleştiri veya suçlamayı kabullenmek: Bir hata veya problem ortaya çıktığında, kişinin suçu veya hataları üzerine alarak diğerlerinin üzerinden bu yükü kaldırması söz konusu olabilir.
# 3. Bir konuda inisiyatif kullanmak: Belirli bir konuda gereken adımları atan ve o konuda girişimde bulunan kişi için kullanılır.
# 4. Bir durumun veya problemle ilgilenmeyi kabul etmek: Bir meseleyle veya zorluğu doğrudan ele almayı üstlenmek anlamında kullanılabilir.
# 5. Acil durumda liderlik yapmak: Beklenmedik bir durumda ön planda olmayı ve yönetimi ele almayı ifade eder.

# %%
prompt = f"""
"{idiom}" deyiminin bir önceki mesajda listelenen her bir durum için {category} anlamda yer aldığı dört farklı cümle oluştur. İlk cümle uzun ve detaylı, ikinci cümle soru formunda, üçüncü cümle olumsuz yapıda, dördüncü cümlede deyimi oluşturan kelimeler arasına başka kelimeler girmiş biçimde olmalı. Lütfen bu deyimin kelime kökleri değiştirmeden. Her kategori için 4 farklı cümle oluşturmalısın.Yanıt olarak sadace bu cümleleri dön. Deyimin kelime köklerini değiştirmeyerek.
"""

# %%
print(prompt)
responses = []
for i in range(step):
    result = chat_session.get_completion(prompt)
    responses.append(result)
# Out:
# "Üstüne almak" deyiminin bir önceki mesajda listelenen her bir durum için mecaz anlamda yer aldığı dört farklı cümle oluştur. İlk cümle uzun ve detaylı, ikinci cümle soru formunda, üçüncü cümle olumsuz yapıda, dördüncü cümlede deyimi oluşturan kelimeler arasına başka kelimeler girmiş biçimde olmalı. Lütfen bu deyimin kelime kökleri değiştirmeden. Her kategori için 4 farklı cümle oluşturmalısın.Yanıt olarak sadace bu cümleleri dön. Deyimin kelime köklerini değiştirmeyerek.

# %%
responses
# Out:
# ['1. Bir projenin ya da işin sorumluluğunu üzerine almak:\n   - Projeyi başarıya ulaştırmak için gereken her türlü çabayı göstermeye hazır olduğunu belirten baş mühendis, tüm zorlukları göz önünde bulundurarak bu büyük sorumluluğu üstüne aldı.\n   - Bu zorlu projenin sorumluluğunu üstüne almak istiyor musun?\n   - Ne yazık ki, kimsenin bu karmaşık projenin sorumluluğunu üstüne almak istemediği görülüyor.\n   - Tüm zorluklarına rağmen, bu projenin sorumluluğunu tune bir biçimde üzerine alarak herkesi şaşırttı.\n\n2. Eleştiri veya suçlamayı kabullenmek:\n   - Tartışmanın ardından, söylediği sözlerin yarattığı yanlış anlamaları düzeltmek adına tüm suçlamaları üstüne alarak hatalarını kabul etti.\n   - Yapılan bu hatalar için üstüne almak gerektiğinin farkında mısın?\n   - Kimse açıkça hatasını kabul edip eleştiriyi üstüne almak istemedi.\n   - Verilen yoğun eleştirilere rağmen, hatalarını bir üstüne alarak kabullenmekten çekinmedi.\n\n3. Bir konuda inisiyatif kullanmak:\n   - Pazarlama departmanında yaşanan düşüşü analiz edip çözüm yolları bulabilmek için inisiyatifi üstüne alarak ekibi motive etti.\n   - Bu krizi yönetmek için inisiyatifini üstüne almak üzerine düşünüyor musun?\n   - Maalesef hiçbir yönetici kriz anında inisiyatif kullanmayı üstüne almak istemiyor.\n   - Zor zamanlarda, liderler genellikle inisiyatifi her bir anında üstüne alarak işleri yoluna koymaya çalışır.\n\n4. Bir durumun veya problemle ilgilenmeyi kabul etmek:\n   - Müşteri şikayetlerini daha etkin bir şekilde çözmek amacıyla, müşteri hizmetleri süreçlerinin tümünü gözden geçirmeyi üstüne alarak büyük bir sorumluluk üstlendi.\n   - Bu büyük sorunla ilgilenmek için gönüllü olarak üstüne almak niyetinde misin?\n   - Çevresel düzenlemeler konusunda hiç kimse en karmaşık işlemi üstüne almak istemiyor.\n   - Bu sorunla yüzleşmek için gereken tüm aksiyonları bir üstüne alarak çözüm üretmeye çalıştı.']

# %%
data = [
    {"submission": "Uzun bir günün ardından yatağına uzanan ve gözlerini yavaşça yumarak, kendini uykunun kollarına bırakan Ahmet, tüm stres ve yorgunluklarını bu şekilde bir kenara atıyor.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Sen de gece yatarken gözlerini yumar mısın genellikle?", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Uykuya dalmadan önce gözlerimi asla hemen yummam, genellikle bir süre tavana bakarım.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Uykuya dalmadan önce, genellikle gözlerimi yavaş yavaş yumarak, rahatlamayı tercih ederim.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Yaz günlerinde parkta koşarken aniden karşısına çıkan güneşin parlak ışığına doğrudan maruz kalan Elif, refleks olarak gözlerini yumar ve başını biraz öne eğer.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Güneşe bakarken gözlerini yumar mısın, yoksa başka bir yöntem kullanır mısın?", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Güneşe doğrudan bakarken, gözlerimi yummam asla iyi bir fikir değil, çünkü bu, görsel algılamamı tamamen engelliyor.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Güneşin kuvvetli ışığına maruz kaldığında, çoğu insan doğal olarak gözlerini bir anlığına yumarak korumaya alır.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Göz doktoruna ziyarette bulunan Murat, görme keskinliğini değerlendirmek için yapılan test sırasında, doktorun talimatları üzerine sol gözünü yumar, sağ gözüyle harfleri okumaya çalışır.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Göz sağlığı kontrolünde doktorun isteği üzerine bir gözünü yumar mıydın?", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Göz doktoru bana bir gözümü yumarak harfleri okumamı söylemişti, fakat ben yanlışlıkla iki gözümü de yummadım.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Göz muayenesi sırasında, genellikle doktorun yönlendirmesi ile bir gözümü kısa süreliğine yumarak diğer gözümün görme yeteneğini test ederim.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Düğünde fotoğrafçı, fotoğrafını çekmek üzere olduğu sırada aniden flaşı patlatınca, Deniz doğal bir reaksiyon olarak hızla gözlerini yumar ve birkaç saniye sonra yeniden açar.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Fotoğraf çekerken birdenbire flaş patladığında gözlerini yumar mısın?", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Fotoğraf çekilirken genelde gözlerimi yummam, çünkü flaşın gözüme zarar vereceğini düşünmüyorum.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},
    {"submission": "Flaşın ani patlamasıyla genellikle hemen gözlerimi bir refleks olarak yumarak kendimi koruma altına alırım.", "category": "gerçek", "idiom": "Göz yummak", "type": "Enhanced-prompting"},

]
new_df=pd.DataFrame(data)
new_df
# Out:
#                                            submission category       idiom  \
# 0   Uzun bir günün ardından yatağına uzanan ve göz...   gerçek  Göz yummak
# 1   Sen de gece yatarken gözlerini yumar mısın gen...   gerçek  Göz yummak
# 2   Uykuya dalmadan önce gözlerimi asla hemen yumm...   gerçek  Göz yummak
# 3   Uykuya dalmadan önce, genellikle gözlerimi yav...   gerçek  Göz yummak
# 4   Yaz günlerinde parkta koşarken aniden karşısın...   gerçek  Göz yummak
# 5   Güneşe bakarken gözlerini yumar mısın, yoksa b...   gerçek  Göz yummak
# 6   Güneşe doğrudan bakarken, gözlerimi yummam asl...   gerçek  Göz yummak
# 7   Güneşin kuvvetli ışığına maruz kaldığında, çoğ...   gerçek  Göz yummak
# 8   Göz doktoruna ziyarette bulunan Murat, görme k...   gerçek  Göz yummak
# 9   Göz sağlığı kontrolünde doktorun isteği üzerin...   gerçek  Göz yummak
# 10  Göz doktoru bana bir gözümü yumarak harfleri o...   gerçek  Göz yummak
# 11  Göz muayenesi sırasında, genellikle doktorun y...   gerçek  Göz yummak
# 12  Düğünde fotoğrafçı, fotoğrafını çekmek üzere o...   gerçek  Göz yummak
# 13  Fotoğraf çekerken birdenbire flaş patladığında...   gerçek  Göz yummak
# 14  Fotoğraf çekilirken genelde gözlerimi yummam, ...   gerçek  Göz yummak
# 15  Flaşın ani patlamasıyla genellikle hemen gözle...   gerçek  Göz yummak
#
#                   type
# 0   Enhanced-prompting
# 1   Enhanced-prompting
# 2   Enhanced-prompting
# 3   Enhanced-prompting
# 4   Enhanced-prompting
# 5   Enhanced-prompting
# 6   Enhanced-prompting
# 7   Enhanced-prompting
# 8   Enhanced-prompting
# 9   Enhanced-prompting
# 10  Enhanced-prompting
# 11  Enhanced-prompting
# 12  Enhanced-prompting
# 13  Enhanced-prompting
# 14  Enhanced-prompting
# 15  Enhanced-prompting

# %%
def parse_and_structure_data(raw_responses_list, idiom, category, response_type):
    structured_data = []
    # Iterate through each block of responses
    for block in raw_responses_list:
        # Split each block into individual lines
        lines = block.split('\n')
        # Skip the header line (assumes the header is the first line)
        for line in lines[1:]:  # this skips the header which is lines[0]
            # Check if the line contains an actual sentence
            if line.strip() and '-' in line:
                # Remove the bullet point and any leading/trailing spaces
                sentence = line.split('-', 1)[-1].strip()
                # Append the structured tuple
                structured_data.append((sentence, category, idiom, response_type))
    return structured_data

# %%
def parse_and_extract_sentences(raw_responses_list):
    # Initialize the list to store sentences
    extracted_sentences = []
    
    # Iterate through each block of responses
    for block in raw_responses_list:
        # Split the block into lines
        lines = block.split('\n')
        
        # Iterate through each line in the block
        for line in lines:
            # Strip whitespace from line
            line = line.strip()
            
            # Check if line starts with a dash followed by a space, indicating a sentence
            if line.startswith('. '):
                # Extract the sentence after the dash and strip leading/trailing whitespace
                sentence = line[2:].strip()
                # Append the cleaned sentence to the list
                extracted_sentences.append((sentence, category, idiom, type))
    
    return extracted_sentences

# %%
def parse_numbered_sentences(raw_texts):
    # Initialize the list to store extracted sentences
    extracted_sentences = []
    
    # Iterate through each text block in the list
    for raw_text in raw_texts:
        # Split the input text into lines
        lines = raw_text.split('\n')
        
        # Iterate through each line in the input text
        for line in lines:
            # Strip any leading/trailing whitespace from the line
            line = line.strip()
            
            # Check if the line starts with a numeric prefix followed by a dot and space (e.g., '1. ')
            if line.startswith(('1. ', '2. ', '3. ', '4. ')):
                # Extract the sentence after the numeric prefix
                sentence = line.split('. ', 1)[-1]
                # Append the extracted sentence to the list
                extracted_sentences.append((sentence, category, idiom, type))
    
    return extracted_sentences

# %%
parsed_data = parse_and_structure_data(responses, idiom, category, type)
parsed_data
# Out:
# [('Projeyi başarıya ulaştırmak için gereken her türlü çabayı göstermeye hazır olduğunu belirten baş mühendis, tüm zorlukları göz önünde bulundurarak bu büyük sorumluluğu üstüne aldı.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Bu zorlu projenin sorumluluğunu üstüne almak istiyor musun?',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Ne yazık ki, kimsenin bu karmaşık projenin sorumluluğunu üstüne almak istemediği görülüyor.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Tüm zorluklarına rağmen, bu projenin sorumluluğunu tune bir biçimde üzerine alarak herkesi şaşırttı.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Tartışmanın ardından, söylediği sözlerin yarattığı yanlış anlamaları düzeltmek adına tüm suçlamaları üstüne alarak hatalarını kabul etti.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Yapılan bu hatalar için üstüne almak gerektiğinin farkında mısın?',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Kimse açıkça hatasını kabul edip eleştiriyi üstüne almak istemedi.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Verilen yoğun eleştirilere rağmen, hatalarını bir üstüne alarak kabullenmekten çekinmedi.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Pazarlama departmanında yaşanan düşüşü analiz edip çözüm yolları bulabilmek için inisiyatifi üstüne alarak ekibi motive etti.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Bu krizi yönetmek için inisiyatifini üstüne almak üzerine düşünüyor musun?',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Maalesef hiçbir yönetici kriz anında inisiyatif kullanmayı üstüne almak istemiyor.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Zor zamanlarda, liderler genellikle inisiyatifi her bir anında üstüne alarak işleri yoluna koymaya çalışır.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Müşteri şikayetlerini daha etkin bir şekilde çözmek amacıyla, müşteri hizmetleri süreçlerinin tümünü gözden geçirmeyi üstüne alarak büyük bir sorumluluk üstlendi.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Bu büyük sorunla ilgilenmek için gönüllü olarak üstüne almak niyetinde misin?',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Çevresel düzenlemeler konusunda hiç kimse en karmaşık işlemi üstüne almak istemiyor.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting'),
#  ('Bu sorunla yüzleşmek için gereken tüm aksiyonları bir üstüne alarak çözüm üretmeye çalıştı.',
#   'mecaz',
#   'Üstüne almak',
#   'Enhanced-prompting')]

# %%
new_df= pd.DataFrame(parsed_data, columns=["submission", "category", "idiom", "type"])
new_df
# Out:
#                                            submission category         idiom  \
# 0   Projeyi başarıya ulaştırmak için gereken her t...    mecaz  Üstüne almak
# 1   Bu zorlu projenin sorumluluğunu üstüne almak i...    mecaz  Üstüne almak
# 2   Ne yazık ki, kimsenin bu karmaşık projenin sor...    mecaz  Üstüne almak
# 3   Tüm zorluklarına rağmen, bu projenin sorumlulu...    mecaz  Üstüne almak
# 4   Tartışmanın ardından, söylediği sözlerin yarat...    mecaz  Üstüne almak
# 5   Yapılan bu hatalar için üstüne almak gerektiği...    mecaz  Üstüne almak
# 6   Kimse açıkça hatasını kabul edip eleştiriyi üs...    mecaz  Üstüne almak
# 7   Verilen yoğun eleştirilere rağmen, hatalarını ...    mecaz  Üstüne almak
# 8   Pazarlama departmanında yaşanan düşüşü analiz ...    mecaz  Üstüne almak
# 9   Bu krizi yönetmek için inisiyatifini üstüne al...    mecaz  Üstüne almak
# 10  Maalesef hiçbir yönetici kriz anında inisiyati...    mecaz  Üstüne almak
# 11  Zor zamanlarda, liderler genellikle inisiyatif...    mecaz  Üstüne almak
# 12  Müşteri şikayetlerini daha etkin bir şekilde ç...    mecaz  Üstüne almak
# 13  Bu büyük sorunla ilgilenmek için gönüllü olara...    mecaz  Üstüne almak
# 14  Çevresel düzenlemeler konusunda hiç kimse en k...    mecaz  Üstüne almak
# 15  Bu sorunla yüzleşmek için gereken tüm aksiyonl...    mecaz  Üstüne almak
#
#                   type
# 0   Enhanced-prompting
# 1   Enhanced-prompting
# 2   Enhanced-prompting
# 3   Enhanced-prompting
# 4   Enhanced-prompting
# 5   Enhanced-prompting
# 6   Enhanced-prompting
# 7   Enhanced-prompting
# 8   Enhanced-prompting
# 9   Enhanced-prompting
# 10  Enhanced-prompting
# 11  Enhanced-prompting
# 12  Enhanced-prompting
# 13  Enhanced-prompting
# 14  Enhanced-prompting
# 15  Enhanced-prompting

# %%
df_structured = pd.concat([df_structured, new_df], ignore_index=True)
df_structured
# Out:
#                                            submission category         idiom  \
# 0   Toplantıdaki eleştirileri üstüne alındı ve hem...    mecaz  Üstüne almak
# 1   Hoca sınıfta genel bir uyarı yaptığında, herke...    mecaz  Üstüne almak
# 2   Projedeki aksaklıklar geçtiğimiz hafta ortaya ...    mecaz  Üstüne almak
# 3   Her ne kadar takım olarak kaybetmiş olsalar da...    mecaz  Üstüne almak
# 4   Öğretmen ders anlatırken yapılan hataları öğre...    mecaz  Üstüne almak
# ..                                                ...      ...           ...
# 71  Zor zamanlarda, liderler genellikle inisiyatif...    mecaz  Üstüne almak
# 72  Müşteri şikayetlerini daha etkin bir şekilde ç...    mecaz  Üstüne almak
# 73  Bu büyük sorunla ilgilenmek için gönüllü olara...    mecaz  Üstüne almak
# 74  Çevresel düzenlemeler konusunda hiç kimse en k...    mecaz  Üstüne almak
# 75  Bu sorunla yüzleşmek için gereken tüm aksiyonl...    mecaz  Üstüne almak
#
#                   type
# 0            Zero-shot
# 1            Zero-shot
# 2            Zero-shot
# 3            Zero-shot
# 4            Zero-shot
# ..                 ...
# 71  Enhanced-prompting
# 72  Enhanced-prompting
# 73  Enhanced-prompting
# 74  Enhanced-prompting
# 75  Enhanced-prompting
#
# [76 rows x 4 columns]

# %%
prompt = f"""
Diğer kategoriler ile devam eder misin aynı şekilde ?
"""

# %%
print(prompt)
responses = []
for i in range(step):
    result = chat_session.get_completion(prompt)
    responses.append(result)
# Out:
# Diğer kategoriler ile devam eder misin aynı şekilde ?

# %%
responses
# Out:
# ["**Eğitimde Reformlar Yapmak:**\n1. Maria Montessori, ona adını veren Montessori eğitim sistemiyle, çocukların özgürce keşfetmelerine ve kendi hızlarında öğrenmelerine olanak tanıyarak eğitim dünyasında devrim niteliğinde bir iz bıraktı.\n2. Dijital eğitim araçları kullanılarak eğitimde daha kalıcı bir iz bırakmak mümkün müdür?\n3. Birçok yeni eğitim modeli, sadece kısa süreli ilgi çekiyor ve uzun vadeli bir iz bırakamıyor.\n4. Finlandiya, öğrenci merkezli yaklaşımı ve yenilikçi eğitim politikaları ile uluslararası alanda başarı grafiğinin sürekli yükselmesiyle eğitim dünyasında sağlam bir iz bıraktı.\n \n**İş Dünyasında Yenilikçilik Yapmak:**\n1. Steve Jobs'un Apple şirketindeki vizyoner liderliği, teknoloji ve tasarımın bir araya geldiği ürünler yaratılmasını sağlayarak tüketici elektroniği sektöründe çağ atlatan bir iz bıraktı.\n2. Sürdürülebilirlik bazlı iş modeli geliştirerek iş dünyasında gerçekten bir iz bırakılabilir mi?\n3. Pek çok startup, piyasada sıra dışı bir etki yaratmayı umsa da yetersiz finansman ve kötü yönetim nedeniyle iz bırakma fırsatını kaybediyor.\n4. Elon Musk, risk almayı seven liderliği ve yenilikçi projeleriyle, özellikle SpaceX ve Tesla üzerinden otomobil ve uzay endüstrilerinde çığır açan bir iz bırakmayı başardı.\n\n**Kültürel Etki Yaratmak:**\n1. J.R.R. Tolkien, Orta Dünya'yı yaratmak ve bu kapsamlı mitolojiyle fantezi edebiyatına muazzam bir boyut kazandırmak suretiyle kültürel bir fenomen yaratmış ve dünya çapında sayısız edebiyat ve sinema eserine ilham kaynağı olarak kültürde derin bir iz bıraktı.\n2. Yeni medya araçlarını kullanarak kültürde kalıcı bir iz bırakmak mümkün mü?\n3. Birçok çağdaş sanatçı, anlamlı kültürel diyaloglar başlatma amacıyla eserler üretse de, genelde hızlı tüketim kültürünün gölgesinde kalıp kalıcı bir iz bırakamıyor.\n4. Frida Kahlo, kendi yaşam öyküsünü ve Meksikalı kimliğini eserlerine yansıtarak, dünya sanatında ve kadın hakları alanında potansiyelini tam anlamıyla gösteren bir iz bıraktı."]

# %%
parsed_data = parse_numbered_sentences(responses)
parsed_data
# Out:
# [('Maria Montessori, ona adını veren Montessori eğitim sistemiyle, çocukların özgürce keşfetmelerine ve kendi hızlarında öğrenmelerine olanak tanıyarak eğitim dünyasında devrim niteliğinde bir iz bıraktı.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Dijital eğitim araçları kullanılarak eğitimde daha kalıcı bir iz bırakmak mümkün müdür?',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Birçok yeni eğitim modeli, sadece kısa süreli ilgi çekiyor ve uzun vadeli bir iz bırakamıyor.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Finlandiya, öğrenci merkezli yaklaşımı ve yenilikçi eğitim politikaları ile uluslararası alanda başarı grafiğinin sürekli yükselmesiyle eğitim dünyasında sağlam bir iz bıraktı.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ("Steve Jobs'un Apple şirketindeki vizyoner liderliği, teknoloji ve tasarımın bir araya geldiği ürünler yaratılmasını sağlayarak tüketici elektroniği sektöründe çağ atlatan bir iz bıraktı.",
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Sürdürülebilirlik bazlı iş modeli geliştirerek iş dünyasında gerçekten bir iz bırakılabilir mi?',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Pek çok startup, piyasada sıra dışı bir etki yaratmayı umsa da yetersiz finansman ve kötü yönetim nedeniyle iz bırakma fırsatını kaybediyor.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Elon Musk, risk almayı seven liderliği ve yenilikçi projeleriyle, özellikle SpaceX ve Tesla üzerinden otomobil ve uzay endüstrilerinde çığır açan bir iz bırakmayı başardı.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ("J.R.R. Tolkien, Orta Dünya'yı yaratmak ve bu kapsamlı mitolojiyle fantezi edebiyatına muazzam bir boyut kazandırmak suretiyle kültürel bir fenomen yaratmış ve dünya çapında sayısız edebiyat ve sinema eserine ilham kaynağı olarak kültürde derin bir iz bıraktı.",
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Yeni medya araçlarını kullanarak kültürde kalıcı bir iz bırakmak mümkün mü?',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Birçok çağdaş sanatçı, anlamlı kültürel diyaloglar başlatma amacıyla eserler üretse de, genelde hızlı tüketim kültürünün gölgesinde kalıp kalıcı bir iz bırakamıyor.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting'),
#  ('Frida Kahlo, kendi yaşam öyküsünü ve Meksikalı kimliğini eserlerine yansıtarak, dünya sanatında ve kadın hakları alanında potansiyelini tam anlamıyla gösteren bir iz bıraktı.',
#   'mecaz',
#   'İz bırakmak',
#   'Enhanced-prompting')]

# %%
new_df= pd.DataFrame(parsed_data, columns=["submission", "category", "idiom", "type"])
new_df
# Out:
#                                            submission category        idiom  \
# 0   Maria Montessori, ona adını veren Montessori e...    mecaz  İz bırakmak
# 1   Dijital eğitim araçları kullanılarak eğitimde ...    mecaz  İz bırakmak
# 2   Birçok yeni eğitim modeli, sadece kısa süreli ...    mecaz  İz bırakmak
# 3   Finlandiya, öğrenci merkezli yaklaşımı ve yeni...    mecaz  İz bırakmak
# 4   Steve Jobs'un Apple şirketindeki vizyoner lide...    mecaz  İz bırakmak
# 5   Sürdürülebilirlik bazlı iş modeli geliştirerek...    mecaz  İz bırakmak
# 6   Pek çok startup, piyasada sıra dışı bir etki y...    mecaz  İz bırakmak
# 7   Elon Musk, risk almayı seven liderliği ve yeni...    mecaz  İz bırakmak
# 8   J.R.R. Tolkien, Orta Dünya'yı yaratmak ve bu k...    mecaz  İz bırakmak
# 9   Yeni medya araçlarını kullanarak kültürde kalı...    mecaz  İz bırakmak
# 10  Birçok çağdaş sanatçı, anlamlı kültürel diyalo...    mecaz  İz bırakmak
# 11  Frida Kahlo, kendi yaşam öyküsünü ve Meksikalı...    mecaz  İz bırakmak
#
#                   type
# 0   Enhanced-prompting
# 1   Enhanced-prompting
# 2   Enhanced-prompting
# 3   Enhanced-prompting
# 4   Enhanced-prompting
# 5   Enhanced-prompting
# 6   Enhanced-prompting
# 7   Enhanced-prompting
# 8   Enhanced-prompting
# 9   Enhanced-prompting
# 10  Enhanced-prompting
# 11  Enhanced-prompting

# %%
df_structured = pd.concat([df_structured, new_df], ignore_index=True)
df_structured
# Out:
#                                            submission category        idiom  \
# 0   Büyük yazar, kalemiyle edebiyat dünyasında der...    mecaz  İz bırakmak
# 1   O başarılı bilim insanı, tıp alanında yaptığı ...    mecaz  İz bırakmak
# 2   Hayırsever iş insanı, yaptığı yardımlarla topl...    mecaz  İz bırakmak
# 3   Olağanüstü bir lider olan o, halkının kalbinde...    mecaz  İz bırakmak
# 4   Yenilikçi fikirleriyle genç girişimci, teknolo...    mecaz  İz bırakmak
# ..                                                ...      ...          ...
# 83  Elon Musk, risk almayı seven liderliği ve yeni...    mecaz  İz bırakmak
# 84  J.R.R. Tolkien, Orta Dünya'yı yaratmak ve bu k...    mecaz  İz bırakmak
# 85  Yeni medya araçlarını kullanarak kültürde kalı...    mecaz  İz bırakmak
# 86  Birçok çağdaş sanatçı, anlamlı kültürel diyalo...    mecaz  İz bırakmak
# 87  Frida Kahlo, kendi yaşam öyküsünü ve Meksikalı...    mecaz  İz bırakmak
#
#                   type
# 0            Zero-shot
# 1            Zero-shot
# 2            Zero-shot
# 3            Zero-shot
# 4            Zero-shot
# ..                 ...
# 83  Enhanced-prompting
# 84  Enhanced-prompting
# 85  Enhanced-prompting
# 86  Enhanced-prompting
# 87  Enhanced-prompting
#
# [88 rows x 4 columns]

# %%
class ChatSession:
    def __init__(self, category, model=model):
        self.model = model
        system_message = f"Türkçe, anadiliniz olduğundan, dilimizi zengin ve yaratıcı biçimlerde kullanmalısın. Lütfen cümlelerinizi tekrar kullanmaktan kaçının ve deyimleri doğru ve {category} anlamıyla kullanarak cümleler oluşturun. Deyimin kelime köklerini değiştirmeyerek. İnsan isimlerini kullanarak cümle kurmamalısın !"
        print(system_message)
        self.messages = [
            {"role": "system", "content": system_message}
        ]

    def get_completion(self, user_prompt):
        # Add the new user message
        self.messages.append({"role": "user", "content": user_prompt})
        
        # Make the API call
        response = client.chat.completions.create(
            model=self.model,
            messages=self.messages,
        )

        # Retrieve the response and append to messages to maintain context
        ai_response = response.choices[0].message.content.strip()
        self.messages.append({"role": "assistant", "content": ai_response})
        response_df = pd.DataFrame(columns=["raw_response", "idiom","type","category"])
        new_entry = {
            "raw_response": ai_response,
            "idiom": idiom,
            "type": type,
            "category":category
        }
        response_df = response_df.append(new_entry, ignore_index=True)
        response_df.to_csv('response_data.csv', mode='a', header=False, index=False)
        return ai_response

# %%
chat_session = ChatSession(category=category)
# Out:
# Türkçe, anadiliniz olduğundan, dilimizi zengin ve yaratıcı biçimlerde kullanmalısın. Lütfen cümlelerinizi tekrar kullanmaktan kaçının ve deyimleri doğru ve mecaz anlamıyla kullanarak cümleler oluşturun. Deyimin kelime köklerini değiştirmeyerek. İnsan isimlerini kullanarak cümle kurmamalısın !

# %%
prompt = f"""
"{idiom}" deyimini {category} anlamda kullanarak anlamda kullanarak, farklı cümle yapılarıyla 6 yeni cümle oluştur. Deyimi cümlenin farklı bölümlerinde kullan.Lütfen cümlelerinizi tekrar kullanmaktan kaçının
"""
print(prompt)
print("\n")
responses = []
for i in range(4):
    result = chat_session.get_completion(prompt)
    responses.append(result)
# Out:
# "Üstüne almak" deyimini mecaz anlamda kullanarak anlamda kullanarak, farklı cümle yapılarıyla 6 yeni cümle oluştur. Deyimi cümlenin farklı bölümlerinde kullan.Lütfen cümlelerinizi tekrar kullanmaktan kaçının

# %%
responses
# Out:
# ['1. Kimse suçu kabul etmek istemezken, o, tüm hataları üstüne alarak cesur bir tavır sergiledi.\n2. Gerçekten hatalı olanın kim olduğunu bilmemesine rağmen, arkadaşının üstüne alındığı anlaşmazlıkta haksız yere eleştirildi.\n3. Herkesin sessiz kaldığı toplantıda, sorumluluğu üstüne almak onun liderlik niteliklerini gözler önüne serdi.\n4. Projede yaşanan aksaklıklar konuşulurken, olayı direkt üstüne alarak tüm ekip adına özür diledi.\n5. İş yerinde yaşanan sorunları her zaman üstüne alan kişi, çözüm yollarını da en hızlı bulandır.\n6. Kriz anında gereken adımları atan ve sorunun çözümünü üstüne almakta tereddüt etmeyen yönetici, tüm çalışanlar tarafından takdir topladı.',
#  '1. Eleştirileri üstüne alarak iyileştirme yolunda önemli bir adım attı.\n2. Fikri beğenilmediğinde, başarısızlığı üstüne alıp, daha iyisini yapmak için kolları sıvadı.\n3. Herkesin çekindiği projeyi üstüne alarak kendini kanıtlama fırsatı buldu.\n4. Yanlış anlaşılan bir durumda, suçu üstüne alarak gergin havayı yumuşattı.\n5. Başkasının yapmaktan korktuğu görevi üstüne alarak, ekibe olan bağlılığını gösterdi.\n6. Grubun karşılaştığı zorlukları üstüne alması, yöneticileri tarafından büyük övgüyle karşılandı.',
#  '1. Toplantıda konuşulan endişeleri üstüne alıp, çözüm önermek için derhal harekete geçti.\n2. Hatalı kararın faturası, onu üstüne alan cesur personel tarafından ödendi.\n3. Herkes sus pusken, o, tüm soruları üstüne alıp, cevaplamaya başladı.\n4. İşler kötü gitmeye başlayınca, bu durumu üstüne alarak bir dizi iyileştirme önerisinde bulundu.\n5. Masadaki tartışmalarda genellikle kimse suçlamaları üstüne almazken, o, takım ruhunu korumak adına öne çıktı.\n6. Tartışma sırasında yapılan yıkıcı eleştirileri üzerine alarak, grup içi uyumu korumayı başardı.',
#  '1. Söylenen sözleri kimse üstüne almak istemeyince, ortam bir anda gerildi.\n2. Proje başarısız olduğunda, yaşananların sorumluluğunu üstüne alarak örnek bir liderlik sergiledi.\n3. Eleştirileri üstüne almak yerine, yapıcı geri bildirim olarak görmeyi tercih etti.\n4. Herkes hatayı kabul etmekten kaçınırken, sorunları üstüne alıp çözüm aramaya başladı.\n5. İş yerindeki her türlü aksaklığı üstüne alarak, diğer çalışanlara destek oldu.\n6. Müşteri şikayetlerini üstüne alıp, doğruca ilgili departmana iletilmesini sağlayarak, şirketin itibarını korumuş oldu.']

# %%
def parse_and_structure_data(raw_responses_list, idiom, category, response_type):
    # Initialize the list to store structured data
    structured_data = []
    # Iterate through each block of responses
    for block in raw_responses_list:
        # Split each block into individual sentences
        sentences = block.split('\n')
        # Remove the numbering from each sentence and strip leading/trailing whitespace
        clean_sentences = [sentence.split('. ', 1)[-1].strip() for sentence in sentences]
        # For each sentence, append a tuple with the structured data
        for sentence in clean_sentences:
            structured_data.append((sentence, category, idiom, response_type))
    return structured_data

# %%
structured_data = parse_and_structure_data(responses, idiom, category, type)

new_df= pd.DataFrame(structured_data, columns=["submission", "category", "idiom", "type"])
new_df
# Out:
#                                            submission category         idiom  \
# 0   Kimse suçu kabul etmek istemezken, o, tüm hata...    mecaz  Üstüne almak
# 1   Gerçekten hatalı olanın kim olduğunu bilmemesi...    mecaz  Üstüne almak
# 2   Herkesin sessiz kaldığı toplantıda, sorumluluğ...    mecaz  Üstüne almak
# 3   Projede yaşanan aksaklıklar konuşulurken, olay...    mecaz  Üstüne almak
# 4   İş yerinde yaşanan sorunları her zaman üstüne ...    mecaz  Üstüne almak
# 5   Kriz anında gereken adımları atan ve sorunun ç...    mecaz  Üstüne almak
# 6   Eleştirileri üstüne alarak iyileştirme yolunda...    mecaz  Üstüne almak
# 7   Fikri beğenilmediğinde, başarısızlığı üstüne a...    mecaz  Üstüne almak
# 8   Herkesin çekindiği projeyi üstüne alarak kendi...    mecaz  Üstüne almak
# 9   Yanlış anlaşılan bir durumda, suçu üstüne alar...    mecaz  Üstüne almak
# 10  Başkasının yapmaktan korktuğu görevi üstüne al...    mecaz  Üstüne almak
# 11  Grubun karşılaştığı zorlukları üstüne alması, ...    mecaz  Üstüne almak
# 12  Toplantıda konuşulan endişeleri üstüne alıp, ç...    mecaz  Üstüne almak
# 13  Hatalı kararın faturası, onu üstüne alan cesur...    mecaz  Üstüne almak
# 14  Herkes sus pusken, o, tüm soruları üstüne alıp...    mecaz  Üstüne almak
# 15  İşler kötü gitmeye başlayınca, bu durumu üstün...    mecaz  Üstüne almak
# 16  Masadaki tartışmalarda genellikle kimse suçlam...    mecaz  Üstüne almak
# 17  Tartışma sırasında yapılan yıkıcı eleştirileri...    mecaz  Üstüne almak
# 18  Söylenen sözleri kimse üstüne almak istemeyinc...    mecaz  Üstüne almak
# 19  Proje başarısız olduğunda, yaşananların soruml...    mecaz  Üstüne almak
# 20  Eleştirileri üstüne almak yerine, yapıcı geri ...    mecaz  Üstüne almak
# 21  Herkes hatayı kabul etmekten kaçınırken, sorun...    mecaz  Üstüne almak
# 22  İş yerindeki her türlü aksaklığı üstüne alarak...    mecaz  Üstüne almak
# 23  Müşteri şikayetlerini üstüne alıp, doğruca ilg...    mecaz  Üstüne almak
#
#                   type
# 0   Enhanced-prompting
# 1   Enhanced-prompting
# 2   Enhanced-prompting
# 3   Enhanced-prompting
# 4   Enhanced-prompting
# 5   Enhanced-prompting
# 6   Enhanced-prompting
# 7   Enhanced-prompting
# 8   Enhanced-prompting
# 9   Enhanced-prompting
# 10  Enhanced-prompting
# 11  Enhanced-prompting
# 12  Enhanced-prompting
# 13  Enhanced-prompting
# 14  Enhanced-prompting
# 15  Enhanced-prompting
# 16  Enhanced-prompting
# 17  Enhanced-prompting
# 18  Enhanced-prompting
# 19  Enhanced-prompting
# 20  Enhanced-prompting
# 21  Enhanced-prompting
# 22  Enhanced-prompting
# 23  Enhanced-prompting

# %%
df_structured = pd.concat([df_structured, new_df], ignore_index=True)
df_structured
# Out:
#                                            submission category         idiom  \
# 0   Toplantıdaki eleştirileri üstüne alındı ve hem...    mecaz  Üstüne almak
# 1   Hoca sınıfta genel bir uyarı yaptığında, herke...    mecaz  Üstüne almak
# 2   Projedeki aksaklıklar geçtiğimiz hafta ortaya ...    mecaz  Üstüne almak
# 3   Her ne kadar takım olarak kaybetmiş olsalar da...    mecaz  Üstüne almak
# 4   Öğretmen ders anlatırken yapılan hataları öğre...    mecaz  Üstüne almak
# ..                                                ...      ...           ...
# 95  Proje başarısız olduğunda, yaşananların soruml...    mecaz  Üstüne almak
# 96  Eleştirileri üstüne almak yerine, yapıcı geri ...    mecaz  Üstüne almak
# 97  Herkes hatayı kabul etmekten kaçınırken, sorun...    mecaz  Üstüne almak
# 98  İş yerindeki her türlü aksaklığı üstüne alarak...    mecaz  Üstüne almak
# 99  Müşteri şikayetlerini üstüne alıp, doğruca ilg...    mecaz  Üstüne almak
#
#                   type
# 0            Zero-shot
# 1            Zero-shot
# 2            Zero-shot
# 3            Zero-shot
# 4            Zero-shot
# ..                 ...
# 95  Enhanced-prompting
# 96  Enhanced-prompting
# 97  Enhanced-prompting
# 98  Enhanced-prompting
# 99  Enhanced-prompting
#
# [100 rows x 4 columns]

# %%
# Define the path for the CSV file
file_path = 'gpt4_tr_mecaz.csv'

# Check if the file exists
if os.path.exists(file_path):
    # Append without writing headers
    df_structured.to_csv(file_path, mode='a', index=False, header=False)
else:
    # Create a new file and write the DataFrame with headers
    df_structured.to_csv(file_path, mode='w', index=False, header=True)
