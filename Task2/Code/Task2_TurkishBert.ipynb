# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import Trainer, TrainingArguments
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import f1_score, classification_report
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
from transformers import AdamW
from tqdm import tqdm

# %%
language="tr"
modelname="TurkishBert"
input = "gpt4"
test = "Dodiom"
filtered= True

# %%
if input == "gpt4":
  gpt4_flag=True
else:
  gpt4_flag=False

# %%
# JP encoding='euc-jp' other encoding normal CHECK ALWAYS DATASETS
df_train = pd.read_csv(f'train_gpt4_tr_zero_shot.csv')
df_eval = pd.read_csv(f'eval_gpt4_tr_zero_shot.csv')
df_test = pd.read_csv(f'dodiom_tr_test.csv')

# %%
def get_category_mapping(language):
    if language in ['en', 'jp']:
        category_mapping = {
            'figurative': 'idiom',
            'literal': 'nonidiom'
        }
    elif language == 'tr':
        category_mapping = {
            'mecaz': 'idiom',
            'gerçek': 'nonidiom'
        }
    elif language == 'it':
        category_mapping = {
            'figurato': 'idiom',
            'letterale': 'nonidiom'
        }
    else:
        raise ValueError(f"Language '{language}' is not supported.")

    return category_mapping

# %%
category_mapping = get_category_mapping(language)
print(category_mapping)
# Out:
# {'mecaz': 'idiom', 'gerçek': 'nonidiom'}

# %%
if gpt4_flag or language in ['en', 'jp']:
  df_train['category'] = df_train['category'].map(category_mapping)
df_train
# Out:
#                                              submission  category  \
# 0     Eşitlik için yapılan mücadelelere karşı çıkmak...     idiom
# 1     Oyunun kırılma anı, takımının şampiyonluğa yol...     idiom
# 2     Komşuluk festivali düzenleme görevini üstlenen...     idiom
# 3     Şirketteki başarısızlıkla ilgili yapılan yorum...     idiom
# 4     Sorunları erkenden çözerek kriz anlarında zama...     idiom
# ...                                                 ...       ...
# 3451  Kütüphanede çalışmak için sessiz bir yer almış...  nonidiom
# 3452  Sprinter, yarışın son metresinde zamanı iyi ku...  nonidiom
# 3453  Sergi alanının ortasına bir sanat eseri koydu ...  nonidiom
# 3454  Eski battaniyeyi köpeğin üstünden atmak için n...  nonidiom
# 3455  Konsere zamanında yetişebilmek için ön sırada ...  nonidiom
#
#                 idiom       type
# 0        Karşı çıkmak  Zero-shot
# 1           Yol açmak  Zero-shot
# 2     Kolları sıvamak  Zero-shot
# 3        Üstüne almak  Zero-shot
# 4      Zaman kazanmak  Zero-shot
# ...               ...        ...
# 3451        Yer almak  Zero-shot
# 3452   Zaman kazanmak  Zero-shot
# 3453    Ortaya koymak  Zero-shot
# 3454   Üstünden atmak  Zero-shot
# 3455        Yer almak  Zero-shot
#
# [3456 rows x 4 columns]

# %%
if gpt4_flag or language in ['en', 'jp']:
  df_eval['category'] = df_eval['category'].map(category_mapping)
df_eval
# Out:
#                                             submission  category  \
# 0    Yeni öğrendiği şarkıyı sokak köşesinde söyleye...     idiom
# 1    Bir lider olarak çalışanlarının hatalarını def...     idiom
# 2    Yönetici, iş yerindeki moral ve motivasyonu yü...     idiom
# 3    Şirketteki gizli toplantıyı kazara sızdırınca ...     idiom
# 4    Film eleştirmenleri, yönetmenin eserindeki sim...     idiom
# ..                                                 ...       ...
# 859  Koşu parkurunda, atletler yorulan arkadaşların...  nonidiom
# 860  Kitapçı, yeni gelen kitapları rafa koymadan ön...  nonidiom
# 861  Çocuklar, köpeklerini sıkı bir şekilde tutarak...  nonidiom
# 862  Tiyatro oyuncuları, sahnenin üstüne çıkmak içi...  nonidiom
# 863  O, kum saati alarak üzerine hafifçe elini koyd...  nonidiom
#
#                 idiom       type
# 0          İçi erimek  Zero-shot
# 1    Defterden silmek  Zero-shot
# 2      Nabzını tutmak  Zero-shot
# 3        Ayvayı yemek  Zero-shot
# 4     Üzerinde durmak  Zero-shot
# ..                ...        ...
# 859       Başa geçmek  Zero-shot
# 860         El koymak  Zero-shot
# 861       Sıkı durmak  Zero-shot
# 862       Üste çıkmak  Zero-shot
# 863         El koymak  Zero-shot
#
# [864 rows x 4 columns]

# %%
if language in ['en', 'jp']:
  df_test['category'] = df_test['category'].map(category_mapping)

# %%
df_test
# Out:
#                 idiom                                         submission  \
# 0          adım atmak  Sen bu adama adım mı attın ki, o sana yakınlaş...
# 1          adım atmak    Bütün zorluklara rağmen yeni bir işe adım attı.
# 2          adım atmak  Adım attığı bu hayatın başına ne gibi olaylar ...
# 3          adım atmak  Bölüm başkanı, akademik dünyaya adım atan genç...
# 4          adım atmak                   Yeni bir deneyime adım atıyorum.
# ...               ...                                                ...
# 2079  üzerinde durmak                      Bu ipin üzerinde duramıyorum.
# 2080  üzerinde durmak              İpin üzerinde tek ayağıyla duruyordu.
# 2081  üzerinde durmak            Bilgisayarın üzerinde kitapları duruyor
# 2082  üzerinde durmak         Üzerinde çilekler duran tartı bana uzattı.
# 2083  üzerinde durmak  Ağacın üzerinde dakikalarca duran kediyi kurta...
#
#       category  rating  likes  dislikes  reports idiom_indices  \
# 0        idiom    0.75      3         0        1        [3, 5]
# 1        idiom    1.00      3         0        0        [6, 7]
# 2        idiom    0.75      3         0        1        [0, 1]
# 3        idiom    0.50      1         0        1        [5, 6]
# 4        idiom    0.75      3         0        1        [3, 4]
# ...        ...     ...    ...       ...      ...           ...
# 2079  nonidiom    1.00      5         0        0        [2, 3]
# 2080  nonidiom    1.00      5         0        0        [1, 4]
# 2081  nonidiom    1.00      4         0        0        [1, 3]
# 2082  nonidiom    1.00      1         0        0        [0, 2]
# 2083  nonidiom    1.00      5         0        0        [1, 3]
#
#                       idiom_words  \
# 0               ['adım', 'attın']
# 1                ['adım', 'attı']
# 2              ['Adım', 'attığı']
# 3                ['adım', 'atan']
# 4            ['adım', 'atıyorum']
# ...                           ...
# 2079  ['üzerinde', 'duramıyorum']
# 2080    ['üzerinde', 'duruyordu']
# 2081      ['üzerinde', 'duruyor']
# 2082        ['Üzerinde', 'duran']
# 2083        ['üzerinde', 'duran']
#
#                                                  lemmas  \
# 0     ['se', 'bu', 'ada', 'adım', 'mı', 'atmak', 'ki...
# 1     ['bütün', 'zor', 'rağmen', 'yen', 'bir', 'işem...
# 2     ['adım', 'atmak', 'bu', 'hayat', 'baş', 'ne', ...
# 3     ['bölüm', 'başka', ',', 'akademik', 'Dünya', '...
# 4       ['yen', 'bir', 'deneyim', 'adım', 'atmak', '.']
# ...                                                 ...
# 2079                ['bu', 'ip', 'Üzer', 'durmak', '.']
# 2080       ['ip', 'Üzer', 'tek', 'Ayağ', 'durmak', '.']
# 2081          ['bilgisayar', 'Üzer', 'kitap', 'durmak']
# 2082  ['Üzer', 'Çilek', 'durmak', 'tartı', 'ban', 'u...
# 2083  ['ağaç', 'Üzer', 'dakika', 'durmak', 'kedi', '...
#
#                                                   words
# 0     ['Sen', 'bu', 'adama', 'adım', 'mı', 'attın', ...
# 1     ['Bütün', 'zorluklara', 'rağmen', 'yeni', 'bir...
# 2     ['Adım', 'attığı', 'bu', 'hayatın', 'başına', ...
# 3     ['Bölüm', 'başkanı', ',', 'akademik', 'dünyaya...
# 4     ['Yeni', 'bir', 'deneyime', 'adım', 'atıyorum'...
# ...                                                 ...
# 2079     ['Bu', 'ipin', 'üzerinde', 'duramıyorum', '.']
# 2080  ['İpin', 'üzerinde', 'tek', 'ayağıyla', 'duruy...
# 2081  ['Bilgisayarın', 'üzerinde', 'kitapları', 'dur...
# 2082  ['Üzerinde', 'çilekler', 'duran', 'tartı', 'ba...
# 2083  ['Ağacın', 'üzerinde', 'dakikalarca', 'duran',...
#
# [2084 rows x 11 columns]

# %%
if filtered == True:
  df_train = df_train.groupby(['idiom', 'category']).apply(lambda x: x.sample(n=32, replace=False)).reset_index(drop=True)
  df_eval = df_eval.groupby(['idiom', 'category']).apply(lambda x: x.sample(n=8, replace=False)).reset_index(drop=True)
# Out:
# <ipython-input-58-5d2163afaadf>:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_train = df_train.groupby(['idiom', 'category']).apply(lambda x: x.sample(n=32, replace=False)).reset_index(drop=True)
# <ipython-input-58-5d2163afaadf>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_eval = df_eval.groupby(['idiom', 'category']).apply(lambda x: x.sample(n=8, replace=False)).reset_index(drop=True)

# %%
df_train['category'] = df_train['category'].str.lower()
df_eval['category'] = df_eval['category'].str.lower()
df_test['category'] = df_test['category'].str.lower()

# %%
df_train.head()
# Out:
#                                           submission category       idiom  \
# 0  Kariyerinde yeni bir sayfa açmaya karar verdi ...    idiom  Adım atmak
# 1  Evlilik teklifiyle ilişkilerini bir sonraki se...    idiom  Adım atmak
# 2  Teknoloji sektöründe kariyer yapmaya adım atma...    idiom  Adım atmak
# 3  Sosyal medyada influencer olmaya adım atmak iç...    idiom  Adım atmak
# 4  Yüksek lisans yaparak akademik kariyerine adım...    idiom  Adım atmak
#
#         type
# 0  Zero-shot
# 1  Zero-shot
# 2  Zero-shot
# 3  Zero-shot
# 4  Zero-shot

# %%
df_eval.head()
# Out:
#                                           submission category       idiom  \
# 0  Sağlıklı yaşam yolculuğuna adım atmak, ilk ola...    idiom  Adım atmak
# 1  Çevre koruma bilincini artırmak adına okullard...    idiom  Adım atmak
# 2  Sosyal sorunlara dikkat çekmek adına belgesel ...    idiom  Adım atmak
# 3  Mesleki kariyerinde yükselmek isteyen Ayşe, da...    idiom  Adım atmak
# 4  Şirket global pazarda yer almak için adım atma...    idiom  Adım atmak
#
#         type
# 0  Zero-shot
# 1  Zero-shot
# 2  Zero-shot
# 3  Zero-shot
# 4  Zero-shot

# %%
df_test.head()
# Out:
#         idiom                                         submission category  \
# 0  adım atmak  Sen bu adama adım mı attın ki, o sana yakınlaş...    idiom
# 1  adım atmak    Bütün zorluklara rağmen yeni bir işe adım attı.    idiom
# 2  adım atmak  Adım attığı bu hayatın başına ne gibi olaylar ...    idiom
# 3  adım atmak  Bölüm başkanı, akademik dünyaya adım atan genç...    idiom
# 4  adım atmak                   Yeni bir deneyime adım atıyorum.    idiom
#
#    rating  likes  dislikes  reports idiom_indices           idiom_words  \
# 0    0.75      3         0        1        [3, 5]     ['adım', 'attın']
# 1    1.00      3         0        0        [6, 7]      ['adım', 'attı']
# 2    0.75      3         0        1        [0, 1]    ['Adım', 'attığı']
# 3    0.50      1         0        1        [5, 6]      ['adım', 'atan']
# 4    0.75      3         0        1        [3, 4]  ['adım', 'atıyorum']
#
#                                               lemmas  \
# 0  ['se', 'bu', 'ada', 'adım', 'mı', 'atmak', 'ki...
# 1  ['bütün', 'zor', 'rağmen', 'yen', 'bir', 'işem...
# 2  ['adım', 'atmak', 'bu', 'hayat', 'baş', 'ne', ...
# 3  ['bölüm', 'başka', ',', 'akademik', 'Dünya', '...
# 4    ['yen', 'bir', 'deneyim', 'adım', 'atmak', '.']
#
#                                                words
# 0  ['Sen', 'bu', 'adama', 'adım', 'mı', 'attın', ...
# 1  ['Bütün', 'zorluklara', 'rağmen', 'yeni', 'bir...
# 2  ['Adım', 'attığı', 'bu', 'hayatın', 'başına', ...
# 3  ['Bölüm', 'başkanı', ',', 'akademik', 'dünyaya...
# 4  ['Yeni', 'bir', 'deneyime', 'adım', 'atıyorum'...

# %%
# Encode the 'category' column
label_encoder = LabelEncoder()
df_train['category_encoded'] = label_encoder.fit_transform(df_train['category'])
df_eval['category_encoded'] = label_encoder.transform(df_eval['category'])
df_test['category_encoded'] = label_encoder.transform(df_test['category'])

# %%
df_train
# Out:
#                                              submission  category       idiom  \
# 0     Kariyerinde yeni bir sayfa açmaya karar verdi ...     idiom  Adım atmak
# 1     Evlilik teklifiyle ilişkilerini bir sonraki se...     idiom  Adım atmak
# 2     Teknoloji sektöründe kariyer yapmaya adım atma...     idiom  Adım atmak
# 3     Sosyal medyada influencer olmaya adım atmak iç...     idiom  Adım atmak
# 4     Yüksek lisans yaparak akademik kariyerine adım...     idiom  Adım atmak
# ...                                                 ...       ...         ...
# 2299  Dağcının termosunun içi yavaşça erimeye başlad...  nonidiom  İçi erimek
# 2300  Donmuş göletin içi, baharın ilk sıcak günlerin...  nonidiom  İçi erimek
# 2301  Bahar geldiğinde, göletin içi tamamen erimiş v...  nonidiom  İçi erimek
# 2302  Sobanın üzerine konulan çaydanlığın içi, sıcak...  nonidiom  İçi erimek
# 2303  Taş ocağında bulunan büyük buz kütlesinin içi,...  nonidiom  İçi erimek
#
#            type  category_encoded
# 0     Zero-shot                 0
# 1     Zero-shot                 0
# 2     Zero-shot                 0
# 3     Zero-shot                 0
# 4     Zero-shot                 0
# ...         ...               ...
# 2299  Zero-shot                 1
# 2300  Zero-shot                 1
# 2301  Zero-shot                 1
# 2302  Zero-shot                 1
# 2303  Zero-shot                 1
#
# [2304 rows x 5 columns]

# %%
df_eval
# Out:
#                                             submission  category       idiom  \
# 0    Sağlıklı yaşam yolculuğuna adım atmak, ilk ola...     idiom  Adım atmak
# 1    Çevre koruma bilincini artırmak adına okullard...     idiom  Adım atmak
# 2    Sosyal sorunlara dikkat çekmek adına belgesel ...     idiom  Adım atmak
# 3    Mesleki kariyerinde yükselmek isteyen Ayşe, da...     idiom  Adım atmak
# 4    Şirket global pazarda yer almak için adım atma...     idiom  Adım atmak
# ..                                                 ...       ...         ...
# 571  Evde yapılan vanilyalı dondurmanın içi, dışarı...  nonidiom  İçi erimek
# 572  Laboratuvarda yapılan deney sırasında, reaktif...  nonidiom  İçi erimek
# 573  Zemin katın içi, yoğun karın erimesiyle birlik...  nonidiom  İçi erimek
# 574  Güneşli bir günde dışarıda bırakılan şekerleme...  nonidiom  İçi erimek
# 575  Sıcak tavanın üstüne konulan margarinin içi er...  nonidiom  İçi erimek
#
#           type  category_encoded
# 0    Zero-shot                 0
# 1    Zero-shot                 0
# 2    Zero-shot                 0
# 3    Zero-shot                 0
# 4    Zero-shot                 0
# ..         ...               ...
# 571  Zero-shot                 1
# 572  Zero-shot                 1
# 573  Zero-shot                 1
# 574  Zero-shot                 1
# 575  Zero-shot                 1
#
# [576 rows x 5 columns]

# %%
df_test
# Out:
#                 idiom                                         submission  \
# 0          adım atmak  Sen bu adama adım mı attın ki, o sana yakınlaş...
# 1          adım atmak    Bütün zorluklara rağmen yeni bir işe adım attı.
# 2          adım atmak  Adım attığı bu hayatın başına ne gibi olaylar ...
# 3          adım atmak  Bölüm başkanı, akademik dünyaya adım atan genç...
# 4          adım atmak                   Yeni bir deneyime adım atıyorum.
# ...               ...                                                ...
# 2079  üzerinde durmak                      Bu ipin üzerinde duramıyorum.
# 2080  üzerinde durmak              İpin üzerinde tek ayağıyla duruyordu.
# 2081  üzerinde durmak            Bilgisayarın üzerinde kitapları duruyor
# 2082  üzerinde durmak         Üzerinde çilekler duran tartı bana uzattı.
# 2083  üzerinde durmak  Ağacın üzerinde dakikalarca duran kediyi kurta...
#
#       category  rating  likes  dislikes  reports idiom_indices  \
# 0        idiom    0.75      3         0        1        [3, 5]
# 1        idiom    1.00      3         0        0        [6, 7]
# 2        idiom    0.75      3         0        1        [0, 1]
# 3        idiom    0.50      1         0        1        [5, 6]
# 4        idiom    0.75      3         0        1        [3, 4]
# ...        ...     ...    ...       ...      ...           ...
# 2079  nonidiom    1.00      5         0        0        [2, 3]
# 2080  nonidiom    1.00      5         0        0        [1, 4]
# 2081  nonidiom    1.00      4         0        0        [1, 3]
# 2082  nonidiom    1.00      1         0        0        [0, 2]
# 2083  nonidiom    1.00      5         0        0        [1, 3]
#
#                       idiom_words  \
# 0               ['adım', 'attın']
# 1                ['adım', 'attı']
# 2              ['Adım', 'attığı']
# 3                ['adım', 'atan']
# 4            ['adım', 'atıyorum']
# ...                           ...
# 2079  ['üzerinde', 'duramıyorum']
# 2080    ['üzerinde', 'duruyordu']
# 2081      ['üzerinde', 'duruyor']
# 2082        ['Üzerinde', 'duran']
# 2083        ['üzerinde', 'duran']
#
#                                                  lemmas  \
# 0     ['se', 'bu', 'ada', 'adım', 'mı', 'atmak', 'ki...
# 1     ['bütün', 'zor', 'rağmen', 'yen', 'bir', 'işem...
# 2     ['adım', 'atmak', 'bu', 'hayat', 'baş', 'ne', ...
# 3     ['bölüm', 'başka', ',', 'akademik', 'Dünya', '...
# 4       ['yen', 'bir', 'deneyim', 'adım', 'atmak', '.']
# ...                                                 ...
# 2079                ['bu', 'ip', 'Üzer', 'durmak', '.']
# 2080       ['ip', 'Üzer', 'tek', 'Ayağ', 'durmak', '.']
# 2081          ['bilgisayar', 'Üzer', 'kitap', 'durmak']
# 2082  ['Üzer', 'Çilek', 'durmak', 'tartı', 'ban', 'u...
# 2083  ['ağaç', 'Üzer', 'dakika', 'durmak', 'kedi', '...
#
#                                                   words  category_encoded
# 0     ['Sen', 'bu', 'adama', 'adım', 'mı', 'attın', ...                 0
# 1     ['Bütün', 'zorluklara', 'rağmen', 'yeni', 'bir...                 0
# 2     ['Adım', 'attığı', 'bu', 'hayatın', 'başına', ...                 0
# 3     ['Bölüm', 'başkanı', ',', 'akademik', 'dünyaya...                 0
# 4     ['Yeni', 'bir', 'deneyime', 'adım', 'atıyorum'...                 0
# ...                                                 ...               ...
# 2079     ['Bu', 'ipin', 'üzerinde', 'duramıyorum', '.']                 1
# 2080  ['İpin', 'üzerinde', 'tek', 'ayağıyla', 'duruy...                 1
# 2081  ['Bilgisayarın', 'üzerinde', 'kitapları', 'dur...                 1
# 2082  ['Üzerinde', 'çilekler', 'duran', 'tartı', 'ba...                 1
# 2083  ['Ağacın', 'üzerinde', 'dakikalarca', 'duran',...                 1
#
# [2084 rows x 12 columns]

# %%
class TextDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
# Initialize tokenizer
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-uncased")

# Tokenize the data
train_encodings = tokenizer(list(df_train['submission']), truncation=True, padding=True, return_tensors="pt")
val_encodings = tokenizer(list(df_eval['submission']), truncation=True, padding=True, return_tensors="pt")
test_encodings = tokenizer(list(df_test['submission']), truncation=True, padding=True, return_tensors="pt")
# Convert to torch tensors
train_labels = torch.tensor(df_train['category_encoded'].values)
val_labels = torch.tensor(df_eval['category_encoded'].values)
test_labels = torch.tensor(df_test['category_encoded'].values)

# Prepare to datasets
train_dataset = TextDataset(train_encodings, train_labels)
val_dataset = TextDataset(val_encodings, val_labels)
test_dataset = TextDataset(test_encodings, test_labels)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
num_labels = len(label_encoder.classes_)
model = AutoModelForSequenceClassification.from_pretrained("dbmdz/bert-base-turkish-uncased", num_labels=num_labels)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
optimizer = AdamW(model.parameters(), lr=5e-6)

epochs = 4
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch in tqdm(train_loader):
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    # Average loss across all batches
    avg_train_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch + 1}/{epochs} | Train Loss: {avg_train_loss}")

    # Evaluation step
    model.eval()
    total_eval_accuracy = 0
    for batch in tqdm(val_loader):
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
            outputs = model(**batch)

        logits = outputs.logits
        predictions = torch.argmax(logits, dim=-1)
        accuracy = (predictions == batch['labels']).cpu().numpy().mean() * 100
        total_eval_accuracy += accuracy

    avg_val_accuracy = total_eval_accuracy / len(val_loader)
    print(f"Epoch {epoch + 1}/{epochs} | Validation Accuracy: {avg_val_accuracy:.2f}%")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/288 [00:00<?, ?it/s]<ipython-input-67-845b27163e62>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-67-845b27163e62>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])
# 100%|██████████| 288/288 [00:24<00:00, 11.78it/s]
# Epoch 1/4 | Train Loss: 0.26735816145729685
# 100%|██████████| 72/72 [00:01<00:00, 53.03it/s]
# Epoch 1/4 | Validation Accuracy: 97.92%
# 100%|██████████| 288/288 [00:23<00:00, 12.00it/s]
# Epoch 2/4 | Train Loss: 0.05631400986264149
# 100%|██████████| 72/72 [00:02<00:00, 28.31it/s]
# Epoch 2/4 | Validation Accuracy: 98.09%
#  18%|█▊        | 51/288 [00:04<00:19, 12.31it/s]

# %%
# Ensure the model is in evaluation mode
model.eval()

# Move the model to the appropriate device
model.to(device)

# Initialize variables to track accuracy
total_correct = 0
total_predictions = 0

# Store true labels and predictions for F1 score calculation
all_labels = []
all_predictions = []

# No gradient updates needed for evaluation
with torch.no_grad():
    for batch in test_loader:
        # Move batch to the same device as the model
        batch = {k: v.to(device) for k, v in batch.items()}

        # Forward pass
        outputs = model(**batch)

        # Get predictions
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=-1)

        # Update tracking variables
        total_correct += (predictions == batch['labels']).sum().item()
        total_predictions += predictions.size(0)

        # Store predictions and true labels
        all_predictions.extend(predictions.cpu().numpy())
        all_labels.extend(batch['labels'].cpu().numpy())

# Calculate accuracy
test_accuracy = total_correct / total_predictions
print(f'Test Accuracy: {test_accuracy:.4f}')

# Calculate F1 scores
f1_weighted = f1_score(all_labels, all_predictions, average='weighted')
f1_macro = f1_score(all_labels, all_predictions, average='macro')

print(f'Weighted F1 Score: {f1_weighted:.4f}')
print(f'Macro F1 Score: {f1_macro:.4f}')

# %%
# Generate classification report
report = classification_report(all_labels, all_predictions, digits=4)
print(f'Classification Report for {modelname}, language {language.upper()}, Train {input.upper()}, Test {test.upper()}:')
print(report)
